# %%
a=10   
b=3
print(a/b)
# Out:
# 3.3333333333333335

# %%
a=10
b=3
print(a//b)
# Out:
# 3

# %%
print(f"\n{a//b}"*3)
# Out:
# 3
# 3
# 3

# %%
f=f"\n{a//b}"

# %%
print(f*3)
# Out:
# 3
# 3
# 3

# %%
a=10
b=3
print(str(a//b)*3)
# Out:
# 333

# %%
a=input()
print(a)
# Out:
#  7
# 7

# %%
a=input("Enter your number:")
# Out:
# Enter your number: 67

# %%
print(a*3)
# Out:
# 676767

# %%
a=67
print(a*3)
# Out:
# 201

# %%
a=10
b=3
print((a//b)*3)
# Out:
# 9

# %%
b=input("Enter num:")
# Out:
# Enter num: 6

# %%
print((b)*3)
# Out:
# 666
