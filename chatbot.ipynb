# %%
import random

# %%
greeting = ["hi","hehee","Bye","H R u "]

# %%
user_input= input("you: ")
# Out:
# you:  hi

# %%
if "hi" in user_input.lower():
    print("Bot:", random.choice(greeting))
else:
    print("Bot: I don't understand.")
# Out:
# Bot: H R u
