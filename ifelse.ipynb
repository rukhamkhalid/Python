# %%
print(2**3)
# Out:
# 8

# %%
2**4
# Out:
# 16

# %%
A=10
if a>5:
    print(a)
# Out:
# 10

# %%
a=4
if a>5:
    print(a)
else:
    print(a+5)
# Out:
# 9

# %%
a=int(input())
b=int(input())
if a>b:
    print(a)
else:
    print(b)
# Out:
#  10
#  6
# 10

# %%
a=int(input())
if a>0:
    print("Positive")
elif  a<0:
    print("Negative")
else:
    print("zero")
# Out:
#  20
# Positive

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b:
    if a>c:
        print(a)
elif b>c:
    print(b)
else:
    print(c)
# Out:
#  23
#  28
#  5
# 28
